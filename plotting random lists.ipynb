# %%
#generate multiple random lists and plot them on a graph

import matplotlib.pyplot as plt
import random as rand

ran_num = rand.randint(1,17)

# create some lists
for j in range(0, 3):
    rand_list = []

    for i in range(0, 8):
        rand_list.append(rand.randint(0,10))
    print(rand_list)


    list_1 = rand_list

    range_value = range(len(list_1))

    plt.plot(range_value, list_1)
    plt.xlabel('range of values')
    plt.ylabel('numbers in the list')
    
plt.show()
# Out:
# [0, 0, 4, 3, 0, 1, 6, 3]
# [6, 8, 4, 1, 8, 0, 2, 9]
# [6, 1, 1, 9, 1, 10, 6, 0]
